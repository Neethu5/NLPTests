# %%
file = open('data/london.txt')
text = file.read()
file.close()    

text
# Out:
# 'London is the capital and most populous city of England and the United Kingdom.\nStanding on the River Thames in the south east of the island of Great Britain,\nLondon has been a major settlement for two millennia. It was founded by the\nRomans, who named it Londinium. London\'s ancient core, the City of London,\nlargely retains its 1.12-square-mile (2.9 km2) medieval boundaries. Since at\nleast the 19th century, "London" has also referred to the metropolis around\nthis core, historically split between Middlesex, Essex, Surrey, Kent and\nHertfordshire, which today largely makes up Greater London, a region governed\nby the Mayor of London and the London Assembly.London is a leading global city\nin the arts, commerce, education, entertainment, fashion, finance, healthcare,\nmedia, professional services, research and development, tourism and\ntransportation. It is the world\'s largest financial centre and has the fifth or\nsixth largest metropolitan area GDP in the world. London is oft
# ...

# %%
## sumarization with NLTK
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from string import punctuation
from nltk.probability import FreqDist
from heapq import nlargest
from collections import defaultdict

# everything together
def summarize(text, n):
    sents = sent_tokenize(text)
    
    assert n <= len(sents)
    word_sent = word_tokenize(text.lower())
    _sw = set(stopwords.words('english') + list(punctuation))
    
    word_sent = [word for word in word_sent if word not in _sw]
    freq = FreqDist(word_sent)
    
    ranking = defaultdict(int)
    
    # creating the significance of each sentence
    for i, sent in enumerate(sents):
        for w in word_tokenize(sent.lower()):
            if w in freq:
                ranking[i] += freq[w]
    
    sents_idx = nlargest(n, ranking, key=ranking.get)
    return [sents[j] for j in sorted(sents_idx)]

# %%
# %%time
summarize(text, 3)
# Out:
# Wall time: 185 ms
# ['The small ancient City of London at its\ncore once comprised the whole settlement, but as its urban area grew, the\nCorporation of London resisted attempts to amalgamate the city with its\nsuburbs, causing "London" to be defined in a number of ways for different\npurposes.Forty per cent of Greater London is covered by the London post town,\nwithin which \'LONDON\' forms part of postal addresses.',
#  'A number of universities in\nLondon are outside the University of London system, including Brunel\nUniversity, Imperial College London, Kingston University, London Metropolitan\nUniversity, University of East London, University of West London, University of\nWestminster, London South Bank University, Middlesex University, and University\nof the Arts London (the largest university of art, design, fashion,\ncommunication and the performing arts in Europe).',
# ...

# %%
# %%time
_sw = set(stopwords.words('english') + list(punctuation))
words = word_tokenize(text.lower())
r_words = [word for word in words if word not in _sw]
print(len(r_words))
# Out:
# 8232
# Wall time: 85.3 ms

# %%
import spacy

nlp = spacy.blank('en')
doc = nlp(text)
for token in doc:
    if token in spacy.s
# Out:
# London
# is
# the
# capital
# and
# most
# populous
# city
# of
# England
# and
# the
# United
# Kingdom
# .
#
#
# Standing
# on
# the
# River
# Thames
# in
# the
# south
# east
# of
# the
# island
# of
# Great
# Britain
# ,
#
#
# London
# has
# been
# a
# major
# settlement
# for
# two
# millennia
# .
# It
# was
# founded
# by
# the
#
#
# Romans
# ,
# who
# named
# it
# Londinium
# .
# London
# 's
# ancient
# core
# ,
# the
# City
# of
# London
# ,
#
#
# largely
# retains
# its
# 1.12-square
# -
# mile
# (
# 2.9
# km2
# )
# medieval
# boundaries
# .
# Since
# at
#
#
# least
# the
# 19th
# century
# ,
# "
# London
# "
# has
# also
# referred
# to
# the
# metropolis
# around
#
#
# this
# core
# ,
# historically
# split
# between
# Middlesex
# ,
# Essex
# ,
# Surrey
# ,
# Kent
# and
#
#
# Hertfordshire
# ,
# which
# today
# largely
# makes
# up
# Greater
# London
# ,
# a
# region
# governed
#
#
# by
# the
# Mayor
# of
# London
# and
# the
# London
# Assembly
# .
# London
# is
# a
# ...
